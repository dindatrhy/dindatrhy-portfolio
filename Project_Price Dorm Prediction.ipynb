# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
kos = pd.read_csv('Data_Kos.csv')
kos
# Out:
#     Ukuran Kamar Mandi Dalam Meja Belajar  Wifi  Dapur     Harga
# 0   Besar                 Ya            Ya   Ya     Ya   6500000
# 1   Besar                 Ya            Ya   Ya     Ya   6000000
# 2    Kecil             Tidak         Tidak   Ya  Tidak   2500000
# 3   Sedang                Ya         Tidak   Ya  Tidak   4000000
# 4   Besar                 Ya            Ya   Ya     Ya  18000000
# 5    Kecil                Ya         Tidak   Ya     Ya   4500000
# 6   Sedang             Tidak            Ya   Ya     Ya   5500000
# 7   Sedang                Ya            Ya   Ya     Ya   6500000
# 8    Kecil             Tidak         Tidak   Ya     Ya   5000000
# 9   Besar                 Ya         Tidak   Ya     Ya   5000000
# 10  Sedang             Tidak            Ya   Ya     Ya   4750000
# 11  Sedang                Ya            Ya   Ya     Ya   5750000
# 12  Besar                 Ya            Ya   Ya     Ya  17500000
# ...

# %%
df_harga = kos['Harga']
df_harga
# Out:
# 0      6500000
# 1      6000000
# 2      2500000
# 3      4000000
# 4     18000000
# 5      4500000
# 6      5500000
# 7      6500000
# 8      5000000
# 9      5000000
# 10     4750000
# 11     5750000
# 12    17500000
# 13     3750000
# 14     4500000
# 15     4020000
# 16     4200000
# 17     3500000
# 18    22000000
# 19     5500000
# 20     4500000
# 21     3500000
# 22     4500000
# 23     5500000
# 24     6500000
# 25     5500000
# 26     8000000
# 27     5750000
# 28     7500000
# 29     6500000
# 30     5500000
# 31     6500000
# 32     7000000
# 33     5400000
# 34     4200000
# 35     4500000
# 36     5500000
# 37     5500000
# 38     5700000
# 39     4500000
# 40     4000000
# 41     6100000
# 42     5800000
# 43     4200000
# 44     6000000
# Name: Harga, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle = kos.drop(['Harga', 'Ukuran'], axis=1)

for i in dfle:
    dfle[i] = le.fit_transform(dfle[i])

dfle
# Out:
#     Kamar Mandi Dalam  Meja Belajar   Wifi  Dapur
# 0                   1              1     0      1
# 1                   1              1     0      1
# 2                   0              0     0      0
# 3                   1              0     0      0
# 4                   1              1     0      1
# 5                   1              0     0      1
# 6                   0              1     0      1
# 7                   1              1     0      1
# 8                   0              0     0      1
# 9                   1              0     0      1
# 10                  0              1     0      1
# 11                  1              1     0      1
# 12                  1              1     0      1
# 13                  0              0     0      1
# 14                  0              0     0      1
# 15                  0              0     0      0
# 16                  0              0     0      1
# 17                  0              0     0      0
# ...

# %%
#one hot encoding

df = pd.get_dummies(kos, columns=['Ukuran'])
df.head()
# Out:
#   Kamar Mandi Dalam Meja Belajar  Wifi  Dapur     Harga  Ukuran_Besar   \
# 0                Ya            Ya   Ya     Ya   6500000              1
# 1                Ya            Ya   Ya     Ya   6000000              1
# 2             Tidak         Tidak   Ya  Tidak   2500000              0
# 3                Ya         Tidak   Ya  Tidak   4000000              0
# 4                Ya            Ya   Ya     Ya  18000000              1
#
#    Ukuran_Kecil  Ukuran_Sedang
# 0             0              0
# 1             0              0
# 2             1              0
# 3             0              1
# 4             0              0

# %%
dfle = df.drop(['Harga'], axis=1)

for i in dfle:
    dfle[i] = le.fit_transform(dfle[i])

dfle
# Out:
#     Kamar Mandi Dalam  Meja Belajar   Wifi  Dapur  Ukuran_Besar   \
# 0                   1              1     0      1              1
# 1                   1              1     0      1              1
# 2                   0              0     0      0              0
# 3                   1              0     0      0              0
# 4                   1              1     0      1              1
# 5                   1              0     0      1              0
# 6                   0              1     0      1              0
# 7                   1              1     0      1              0
# 8                   0              0     0      1              0
# 9                   1              0     0      1              1
# 10                  0              1     0      1              0
# 11                  1              1     0      1              0
# 12                  1              1     0      1              1
# ...

# %%
dfle = dfle.drop_duplicates()
dfle
# Out:
#     Kamar Mandi Dalam  Meja Belajar   Wifi  Dapur  Ukuran_Besar   \
# 0                   1              1     0      1              1
# 2                   0              0     0      0              0
# 3                   1              0     0      0              0
# 5                   1              0     0      1              0
# 6                   0              1     0      1              0
# 7                   1              1     0      1              0
# 8                   0              0     0      1              0
# 9                   1              0     0      1              1
# 17                  0              0     0      0              0
# 19                  1              0     0      0              0
# 25                  1              0     0      1              0
# 33                  0              1     0      0              0
# 34                  0              1     0      0              0
# ...

# %%
dataset = dfle.join(kos['Harga'])
dataset
# Out:
#     Kamar Mandi Dalam  Meja Belajar   Wifi  Dapur  Ukuran_Besar   \
# 0                   1              1     0      1              1
# 2                   0              0     0      0              0
# 3                   1              0     0      0              0
# 5                   1              0     0      1              0
# 6                   0              1     0      1              0
# 7                   1              1     0      1              0
# 8                   0              0     0      1              0
# 9                   1              0     0      1              1
# 17                  0              0     0      0              0
# 19                  1              0     0      0              0
# 25                  1              0     0      1              0
# 33                  0              1     0      0              0
# 34                  0              1     0      0              0
# ...

# %%
dataset = dataset.drop(['Wifi'], axis='columns')
dataset.corr()
# Out:
#                    Kamar Mandi Dalam  Meja Belajar      Dapur  Ukuran_Besar   \
# Kamar Mandi Dalam           1.000000      -0.054554  0.196429       0.467707
# Meja Belajar               -0.054554       1.000000 -0.054554       0.272166
# Dapur                       0.196429      -0.054554  1.000000       0.133631
# Ukuran_Besar                0.467707       0.272166  0.133631       1.000000
# Ukuran_Kecil               -0.188982      -0.288675 -0.188982      -0.353553
# Ukuran_Sedang              -0.196429       0.054554  0.071429      -0.467707
# Harga                       0.499645       0.570178  0.436875       0.419620
#
#                    Ukuran_Kecil  Ukuran_Sedang     Harga
# Kamar Mandi Dalam     -0.188982      -0.196429  0.499645
# Meja Belajar          -0.288675       0.054554  0.570178
# Dapur                 -0.188982       0.071429  0.436875
# Ukuran_Besar          -0.353553      -0.467707  0.419620
# Ukuran_Kecil           1.000000      -0.661438 -0.398574
# ...

# %%
dataset.drop_duplicates(keep=False, inplace=True)

# %%
dataset.shape
# Out:
# (15, 7)

# %%
ax = sns.heatmap(dataset.corr(), annot=True)

# %%
#Features and Label
X = dataset.drop(['Harga'], axis=1)
y = dataset['Harga']

from sklearn.model_selection import train_test_split
X_train, X_test,  y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(y_pred.shape)
# Out:
# (3,)

# %%
from sklearn.metrics import mean_absolute_error as mae

error_1 = mae(y_true=y_test, y_pred=y_pred)
error_1
# Out:
# 809788.7686759402

# %%
model_2 = LinearRegression(fit_intercept=False)
model_2 = model_2.fit(X_train, y_train)
y_pred_2 = model_2.predict(X_test)
print(y_pred_2.shape)
# Out:
# (3,)

# %%
error_2 = mae(y_true=y_test, y_pred=y_pred_2)
error_2
# Out:
# 809788.768675942

# %%
from sklearn.neighbors import KNeighborsRegressor

knr = KNeighborsRegressor(n_neighbors=5)
knr.fit(X_train, y_train)
y_pred_knr = knr.predict(X_test)

error_knr = mae(y_test, y_pred_knr)
error_knr
# Out:
# 1226666.6666666667

# %% [markdown]
# # K-FOLD

# %%
from sklearn.model_selection import cross_val_score as cvs

lr1 = LinearRegression()
lr2 = LinearRegression(fit_intercept=False)

for model in [lr1, lr2]:
    ini = model.fit(X_train, y_train)
    y_predict = model.predict(X_test)
    error_ = mae(y_true=y_test, y_pred=y_predict)
    print(error_)
# Out:
# 809788.7686759402
# 809788.768675942

# %%
for model in [lr1, lr2]:
    neg_score = cvs(model, X, y, cv=5, scoring='neg_mean_squared_error')
    score = np.abs(np.mean(neg_score))
    print(score)
# Out:
# 862058219103.0735
# 862058219103.0731

# %%
model.score(X_test, y_test) #ini menghitung r_squared
# Out:
# 0.282803269122761

# %% [markdown]
# # MSE, MAE, RMSE

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

#Calculating MSE, lower the value better it is. 0 means perfect prediction
mse = mean_squared_error(y_test, y_pred)
print('Mean squared error of testing set:', mse)
#Calculating MAE
mae = mean_absolute_error(y_test, y_pred)
print('Mean absolute error of testing set:', mae)
#Calculating RMSE
rmse = np.sqrt(mse)
print('Root Mean Squared Error of testing set:', rmse)
# Out:
# Mean squared error of testing set: 757040993703.7505
# Mean absolute error of testing set: 809788.7686759402
# Root Mean Squared Error of testing set: 870081.0270910121

# %% [markdown]
# # Data Baru

# %%
data_baru = np.array([[1,1,1,1,0,0]])
model.predict(data_baru)
# Out:
# array([6378670.78825347])
